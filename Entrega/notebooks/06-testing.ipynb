# %% [markdown]
# MAE: 3233.0885169118073
# MSE: 37560891.48026618
# R2: 0.4799954420861495
#
# # MAE
# El error medio indica que el modelo se equivoca en promedio alrededor de 3200 usd por predicción
# # MSE
# Es alto porque penaliza fuertemente los errores grandes
# # R2
# Se obtuvo un R² de 0.48, lo que indica que explica que tiene 48% de la variabilidad del precio del vehículo

# %% [markdown]
# - Como mejora a futuro, aplciar técnicas de selección de variables más avanzadas, modelos no lineales como Random Forest o incorporando mayor cantidad de datos, pero debía estudiar demaciado y el tiempo me juega en contra. Dedicado al mejor profe de ciencia de datos!
