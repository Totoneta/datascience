# %%
import pandas as pd

# %%
df = pd.read_csv("../data/original_1_car_pricing.csv") # Data original
df
# Out:
#          index          dateCrawled  \
# 0            0  2016-03-24 11:52:17
# 1            1  2016-03-24 10:58:45
# 2            2  2016-03-14 12:52:21
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# ...        ...                  ...
# 371523  371523  2016-03-14 17:48:27
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371526  371526  2016-03-20 19:41:08
# 371527  371527  2016-03-07 19:39:19
#
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...

# %%
mydf = df.sample(50000, random_state=50000) # Muestras a utilizar del total de datos
mydf
# Out:
#          index          dateCrawled  \
# 293842  293842  2016-03-05 19:53:12
# 361177  361177  2016-03-18 12:39:34
# 242140  242140  2016-04-01 02:36:20
# 215718  215718  2016-03-07 03:36:21
# 350134  350134  2016-03-20 13:44:40
# ...        ...                  ...
# 239424  239424  2016-03-18 22:36:32
# 262914  262914  2016-03-28 20:57:46
# 240512  240512  2016-03-17 14:53:15
# 99472    99472  2016-03-05 17:37:54
# 341942  341942  2016-03-16 21:46:00
#
#                                                      name  seller offerType  \
# 293842  Sitzfelle_fuer_Audi_80_Massanfertigung_guter_Z...  privat   Angebot
# 361177               Fahrzeug_eines_Rentners_zu_verkaufen  privat   Angebot
# 242140             Volkswagen_Golf_1.6_TDI_DPF_BlueMotion  privat   Angebot
# 215718                              MINI_CLUBMAN_COOPER_D  privat   Angebot
# 350134    Smart_smart_fortwo_cdi_coupe_softouch_pulse_dpf  privat   Angebot
# ...

# %%
mydf.reset_index(drop=True, inplace=True) 
mydf.to_csv("../data/1_preprocessing_1_car_pricing.csv")
mydf
# Out:
#         index          dateCrawled  \
# 0      293842  2016-03-05 19:53:12
# 1      361177  2016-03-18 12:39:34
# 2      242140  2016-04-01 02:36:20
# 3      215718  2016-03-07 03:36:21
# 4      350134  2016-03-20 13:44:40
# ...       ...                  ...
# 49995  239424  2016-03-18 22:36:32
# 49996  262914  2016-03-28 20:57:46
# 49997  240512  2016-03-17 14:53:15
# 49998   99472  2016-03-05 17:37:54
# 49999  341942  2016-03-16 21:46:00
#
#                                                     name  seller offerType  \
# 0      Sitzfelle_fuer_Audi_80_Massanfertigung_guter_Z...  privat   Angebot
# 1                   Fahrzeug_eines_Rentners_zu_verkaufen  privat   Angebot
# 2                 Volkswagen_Golf_1.6_TDI_DPF_BlueMotion  privat   Angebot
# 3                                  MINI_CLUBMAN_COOPER_D  privat   Angebot
# 4        Smart_smart_fortwo_cdi_coupe_softouch_pulse_dpf  privat   Angebot
# ...                                                  ...     ...       ...
# ...
